# %%
s={}
type(s)
# Out:
# dict

# %%
s={1,2}
type(s)
# Out:
# set

# %%
s={1:"Sandeep"}
s.get(1)
# Out:
# 'Sandeep'

# %%
d3={4:"Sandeep",2:"Manoj",True:"Ram"}
d3
# Out:
# {4: 'Sandeep', 2: 'Manoj', True: 'Ram'}

# %%
d3[1]
# Out:
# 'Ram'

# %%
d3[1]
# Out:
# 'Ram'

# %%
d3[4]
# Out:
# 'Sandeep'

# %%
d4={"name":"Sandeep","mail":"snadeep@gmail.com","name":"manoj"}

# %%
d4["name"]
# Out:
# 'manoj'

# %%
d5={"compny":"Pw skills","courses":["web dev","data science","java with dsa "]}

# %%
d5["courses"][2]
# Out:
# 'java with dsa '

# %%
d6={"number":[1,2,3,4,5,6],"assignment":(1,2,3,4,5,6),"la_date":{12,23,45,67}}

# %%
d6["mentor"]=["sandeep","ravi","ajain","shiva"]
d6
# Out:
# {'number': [1, 2, 3, 4, 5, 6],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'la_date': {12, 23, 45, 67},
#  'mentor': ['sandeep', 'ravi', 'ajain', 'shiva']}

# %%
list(d6.keys())
# Out:
# ['number', 'assignment', 'la_date', 'mentor']

# %%
list(d6.values())
# Out:
# [[1, 2, 3, 4, 5, 6],
#  (1, 2, 3, 4, 5, 6),
#  {12, 23, 45, 67},
#  ['sandeep', 'ravi', 'ajain', 'shiva']]

# %%
list(d6.items())
# Out:
# [('number', [1, 2, 3, 4, 5, 6]),
#  ('assignment', (1, 2, 3, 4, 5, 6)),
#  ('la_date', {12, 23, 45, 67}),
#  ('mentor', ['sandeep', 'ravi', 'ajain', 'shiva'])]

# %%
d6.pop("number")
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
d6
# Out:
# {'assignment': (1, 2, 3, 4, 5, 6),
#  'la_date': {12, 23, 45, 67},
#  'mentor': ['sandeep', 'ravi', 'ajain', 'shiva']}

# %%
marks=int(input("Enter the no :"))
if marks >=80:
    print("you will part of a not batch")
else:
    print("you will not part of a not batch")
# Out:
# Enter the no : 20
# you will not part of a not batch

# %%
marks=eval(input("enter the marks"))

if marks>=80:
    print("you will part of A0 batch")
elif   marks<80 and marks>=60:
    print("you will be part of A1 batch")
else :
    print("you will part of A2 batch")
# Out:
# enter the marks 10
# you will part of A2 batch

# %%
price=int(input("Enter the price"))
if price>1000:
    print("i will no purchase")
else:
    print("i will purchase")
# Out:
# Enter the price 70000000
# i will no purchase

# %%
l=[1,2,3,4,5,6,6]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 6

# %%
for i in range (len(l)):
    print(l[i] ,end=" ")
# Out:
# 1 2 3 4 5 6 6

# %%
l1=[]
for i in l:
    print(i+1)
    l1.append(i+1)
l1
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 7
# [2, 3, 4, 5, 6, 7, 7]

# %%
l3=["sam","kumar","pw skills","course"]
l=[]
for i in l3:
    var=i
    l.append(var.upper())
l
# Out:
# ['SAM', 'KUMAR', 'PW SKILLS', 'COURSE']

# %%
l=[1,2,3,4,5,6,"sam","kumar","ram","abc",12]

# %%
l1_num=[]
l2_str=[]
for i in l:
    if type(i)==int or type(i)== float:
        l1_num.append(i)
    else:
        l2_str.append(i)
l1_num
l2_str
# Out:
# ['sam', 'kumar', 'ram', 'abc']

# %%
l1_num
# Out:
# [1, 2, 3, 4, 5, 6, 12]

# %%
l2_str
# Out:
# ['sam', 'kumar', 'ram', 'abc']
