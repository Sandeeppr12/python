# %%
def fun():
    pass

# %%
def fun():
    print(" this is my cute function")
fun()
# Out:
#  this is my cute function

# %%
fun()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fun()
#
# NameError: name 'fun' is not defined

# %%
def fun1():
    return "this is my string"

# %%
fun1()
# Out:
# 'this is my string'

# %%
fun1()+" Sandeep"
# Out:
# 'this is my string Sandeep'

# %%
def fun3():
    return "sand",24,33.3,[1,2,3,4]

# %%
a,b,c,d=fun3()

# %%
a
# Out:
# 'sand'

# %%
b
# Out:
# 24

# %%
c
# Out:
# 33.3

# %%
d
# Out:
# [1, 2, 3, 4]

# %%
def test4():
    a=4+8+8
    return a

# %%
test4()
# Out:
# 20

# %%
def test5(a,b,c):
    d=a+b//c
    return d

# %%
test5(2,8,2)
# Out:
# 6

# %%
def test6(a,b):
    return a+b

# %%
test6(2,4)
# Out:
# 6

# %%
test6("ram","shyam")
# Out:
# 'ramshyam'

# %%
l1=[1,2,3,4]
l2=[5,6,7,8]

# %%
test6(l1,l2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 test6(l1,l2)
#
# NameError: name 'test6' is not defined

# %%
l=[1,2,3,4,"sam","kumar",[1,2,3,4,5,6]]

# %%
l1=[]
for i in l:
    if type(i)==int or type(i)==float:
        l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
def test7(l):
    l1=[]
    for i in l:
        if type(i)==int or type(i)==float:
           l1.append(i)
    return l1

# %%
test7(l)
# Out:
# [1, 2, 3, 4]

# %%
def test8( a):
    ''' this is my function to extract numeric data'''
    l=[]
    for i in a:
        if type(i)==list:
            for j in i:
                l.append(j)
        else :
            if type(i)== int or type(i)==float:
                l.append(i)
    return l

# %%
test8(l)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4, 5, 6]

# %%
l
# Out:
# [1, 2, 3, 4, 'sam', 'kumar', [1, 2, 3, 4, 5, 6]]

# %%
def test11(*args):
    return args

# %% [markdown]
# test11()

# %%
test11(1,2,3)
# Out:
# (1, 2, 3)

# %%
test11(l)
# Out:
# ([1, 2, 3, 4, 'sam', 'kumar', [1, 2, 3, 4, 5, 6]],)

# %%
def test12(*sandeep):
    return sandeep

# %%
test12(l)
# Out:
# ([1, 2, 3, 4, 'sam', 'kumar', [1, 2, 3, 4, 5, 6]],)

# %%
def test13(*args ,a):
    return args ,a

# %%
test13(1,2,3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 test13(1,2,3,4,5)
#
# TypeError: test13() missing 1 required keyword-only argument: 'a'

# %%
test13(1,2,3,4, a=13)
# Out:
# ((1, 2, 3, 4), 13)

# %%
def test14(a=23,b=23, c, d):
    return a,b,c,d
# Out:
#   Cell In[28], line 1
#     def test14(a=23,b=23, c, d):
#                           ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def test14(c,d,a=23,b=23):
    return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(1,2)
# Out:
# (23, 23, 1, 2)

# %%
test14(2,5,a=12)
# Out:
# (12, 23, 2, 5)

# %%
def test15(**kwargs):
    return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="Sandeep",c="ameer")
# Out:
# {'a': [1, 2, 3, 4], 'b': 'Sandeep', 'c': 'ameer'}
