# %%
def test1(n,p):
    return n**p

# %%
test1(3,5)
# Out:
# 243

# %%
a=lambda n,p: n**p

# %%
a(3,5)
# Out:
# 243

# %%
add= lambda a,b:a+b

# %%
add(2,3)
# Out:
# 5

# %%
c_to_f=lambda c:(9/5)*c+32

# %%
c_to_f(40)
# Out:
# 104.0

# %%
finding_max=lambda x,y: x if x>y else y

# %%
finding_max(10,39)
# Out:
# 39

# %%
s="sandeep"

# %%
find_length=lambda x:len(x)

# %%
find_length(s)
# Out:
# 7
