# %%
l=[1,2,3,4,5,6,7]
l1=[]
for i in l:
    l1.append(i**2)
l1
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
l1=[i**2 for i in l]
l1
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
l3=[]
for i in l:
    if i%2==0:
        l3.append(i)
l3
# Out:
# [2, 4, 6]

# %%
l1=["sam","ram","ramu","boss","neon"]
[i.upper() for i in l1]
# Out:
# ['SAM', 'RAM', 'RAMU', 'BOSS', 'NEON']

# %%
t=(1,2,3,4,5,6)
list( i**2 for i in t)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
d={"key1":1,"key2":2,"key3":3,"key4":4}

# %%
{k:v**2 for k,v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
{k:v for k,v in  d.items() if v>1}
# Out:
# {'key2': 2, 'key3': 3, 'key4': 4}
