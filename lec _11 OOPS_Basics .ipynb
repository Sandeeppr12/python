# %%
#>>object oriented programming system

# %%
a="Sandeep"
type(a)
# Out:
# str

# %%
b=12

# %%
type(b)
# Out:
# int

# %%
class Car:
    pass

# %%
a =  Car()

# %%
print(type(a))#instance,variable
# Out:
# <class '__main__.Car'>

# %%
class Car:
    def acclarate(self):
        print("Carr is accelerating")

# %%
a=Car()

# %%
a.acclarate()
# Out:
# Carr is accelerating

# %%
#self >>is a variable that represents instance of class

# %%
class Car:
    def accelerate(self):
        print("car is accelareting")
    def brake(self):
        print("car is stopping")

# %%
a=Car()

# %%
a.accelerate()
# Out:
# car is accelareting

# %%
a.brake()
# Out:
# car is stopping

# %%
class Bank:
    amt=1000000
    def deposite(self,amount):
        print("i am trying to deposite money in my bank acount")
    def withdraw(self,amount):
        print("i want to withdraw som mony from my bank account")

# %%
sandeep=Bank()

# %%
sandeep.deposite(2500)
# Out:
# i am trying to deposite money in my bank acount

# %%
sandeep.withdraw(10)
# Out:
# i want to withdraw som mony from my bank account

# %%
sandeep.amt
# Out:
# 1000000

# %%
class Listop:
    n=[1,2,3,4,5,6]
    def evenNo(self,l):
        l1=[]
        for i in l:
            if i%2==0:
                l1.append(i)
        return l1
    
    def oddNo(self,l):
        l2=[]
        for i in l:
            if i%2==1:
                l2.append(i)
        return l2

# %%
  l=[1,2,3,4,5,6]

# %%
k=Listop()

# %%
k.evenNo(l)
# Out:
# [2, 4, 6]

# %%
k.oddNo(l)
# Out:
# [1, 3, 5]

# %%
k.evenNo(k.l)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 k.evenNo(k.l)
#
# AttributeError: 'Listop' object has no attribute 'l'

# %%
class Listop:
    def __init__(self,l):
        self.l1=l
      
    def evenNo(self,l):
        l1=[]
        for i in l:
            if i%2==0:
                l1.append(i)
        return l1
    
    def oddNo(self,l):
        l2=[]
        for i in l:
            if i%2==1:
                l2.append(i)
        return l2

# %%
obj=Listop(l)

# %%
obj.evenNo(l)
# Out:
# [2, 4, 6]

# %%
obj.l
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 obj.l
#
# AttributeError: 'Listop' object has no attribute 'l'

# %%
obj.l1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
class Book:
    def __init__(self,name,author,title):
        self.name_of_book=name
        self.book_author=author
        self.title_name=title

    def extract_detail_name_title(self):
        print(self.name_of_book,self.title_name)

    def extract_detail_name_author(self):
        print(self.name_of_book,self.book_author)

# %%
student1=Book("ML","MURPHY","Linear regression")

# %%
student1.book_author
# Out:
# 'MURPHY'

# %%
student1.name_of_book
# Out:
# 'ML'

# %%
student1.title_name
# Out:
# 'Linear regression'

# %%
student1.extract_detail_name_author()
# Out:
# ML MURPHY

# %% [markdown]
# #OOPS BY SUDHANSU SIR

# %% [markdown]
# #OOPS BY SUDHANSU SIR

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
class pwSkill:
    def welcome(self):
        print("welcome to pw")

# %%
s1=pwSkill()

# %%
s1.welcome()
# Out:
# welcome to pw

# %%
class pwskill:
    def __init__(self,phone_number,email_id,student_id):
        self.phone_number=phone_number
        self.email_id=email_id
        self.student_id=student_id
    def return_student_detail(self):
        return self.student_id,self.email_id,self.phonr_number

# %%
rohan=pwskill(8953291131,"Sandeeppr@gmail.com",12)

# %%
rohan.email_id
# Out:
# 'Sandeeppr@gmail.com'

# %%
rohan.phone_number
# Out:
# 8953291131

# %%
rohan.student_id
# Out:
# 12

# %%
class pwskill:
    def __init__(self,phone_number,email_id,student_id):
        self.phone_number1=phone_number
        self.email_id1=email_id
        self.student_id1=student_id
    def return_student_detail(self):
        return self.student_id1,self.email_id1,self.phone_number1

# %%
rohan=pwskill(8953291131,"Sandeeppr@gmail.com",12)

# %%
rohan.email_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 rohan.email_id
#
# AttributeError: 'pwskill' object has no attribute 'email_id'

# %%
rohan.email_id1
# Out:
# 'Sandeeppr@gmail.com'

# %%
rohan.return_student_detail()
# Out:
# (12, 'Sandeeppr@gmail.com', 8953291131)
